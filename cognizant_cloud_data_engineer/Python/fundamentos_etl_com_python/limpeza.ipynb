# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep = ";", parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.Object, pa.Check.str_matches(r'^([0-1]?[0-9]?)|[2][0-3]:([0-5][0-9]):([0-5][0-9])?$'), nullable=True)     
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 5747    12
# 5748    12
# 5749    12
# 5750    12
# 5751    12
# Name: ocorrencia_dia, Length: 5752, dtype: int64

# %%
df['ocorrencia_uf'].unique()
# Out:
# array(['RJ', 'PA', 'MT', 'RS', 'BA', 'AM', 'PR', 'MG', 'SP', 'DF', 'AC',
#        'TO', 'SC', 'GO', 'MA', 'ES', 'PE', 'RR', 'MS', 'CE', 'AP', 'AL',
#        'RO', 'SE', 'PB', 'PI', 'RN', '**'], dtype=object)

# %%
df['ocorrencia_aerodromo'].unique()
# Out:
# array(['****', 'SBBE', 'SBRJ', 'SBPK', 'SBUY', 'SBCA', 'SBMT', 'SBBR',
#        'SNGU', 'SBGL', 'SBCZ', 'SBPF', 'SBBI', 'SBGR', 'SBPJ', 'SBJC',
#        'SBFL', 'SNCL', 'SBGO', 'SNTY', 'SBSR', 'SBVT', 'SBPC', 'SBSV',
#        'SBCT', 'SBCY', 'SWLC', 'SBJR', 'SBEG', 'SBPR', 'SBLO', 'SBRB',
#        'SBSM', 'SSBL', 'SBMK', 'SBSP', 'SBCF', 'SBUL', 'SWUZ', 'SWNS',
#        'SBFZ', 'SNVR', 'SBPN', 'SSUV', 'SBKP', 'SWNV', 'SBSJ', 'SBML',
#        'SBPA', 'SBME', 'SDPY', 'SWOZ', 'SNEM', 'SBBH', 'SJCY', 'SBSL',
#        'SBMA', 'SWKC', 'SBMO', 'SBJD', 'SDAM', 'SBCJ', 'SNUZ', 'SBPS',
#        'SBJV', 'SNFX', 'SBPL', 'SWXV', 'SBAR', 'SBNF', 'SBRF', 'SSZW',
#        'SWRD', 'SWLV', 'SSGP', 'SDOI', 'SBAE', 'SNDV', 'SSKS', 'SBMG',
#        'SBQV', 'SBIP', 'SBAT', 'SWFR', 'SBBV', 'SBJP', 'SSVN', 'SSPS',
#        'SDPW', 'SBSN', 'SNDT', 'SSKZ', 'SBUR', 'SBTE', '*****', 'SBBU',
#        'SNXT', 'SBRP', 'SSCF', 'SSIE', 'SBCG', 'SBAQ', 'SBIZ', 'SBBP',
# ...

# %%
pd.concat([df['ocorrencia_uf'], df['ocorrencia_aerodromo']]).unique()
# Out:
# array(['RJ', 'PA', 'MT', 'RS', 'BA', 'AM', 'PR', 'MG', 'SP', 'DF', 'AC',
#        'TO', 'SC', 'GO', 'MA', 'ES', 'PE', 'RR', 'MS', 'CE', 'AP', 'AL',
#        'RO', 'SE', 'PB', 'PI', 'RN', '**', '****', 'SBBE', 'SBRJ', 'SBPK',
#        'SBUY', 'SBCA', 'SBMT', 'SBBR', 'SNGU', 'SBGL', 'SBCZ', 'SBPF',
#        'SBBI', 'SBGR', 'SBPJ', 'SBJC', 'SBFL', 'SNCL', 'SBGO', 'SNTY',
#        'SBSR', 'SBVT', 'SBPC', 'SBSV', 'SBCT', 'SBCY', 'SWLC', 'SBJR',
#        'SBEG', 'SBPR', 'SBLO', 'SBRB', 'SBSM', 'SSBL', 'SBMK', 'SBSP',
#        'SBCF', 'SBUL', 'SWUZ', 'SWNS', 'SBFZ', 'SNVR', 'SBPN', 'SSUV',
#        'SBKP', 'SWNV', 'SBSJ', 'SBML', 'SBPA', 'SBME', 'SDPY', 'SWOZ',
#        'SNEM', 'SBBH', 'SJCY', 'SBSL', 'SBMA', 'SWKC', 'SBMO', 'SBJD',
#        'SDAM', 'SBCJ', 'SNUZ', 'SBPS', 'SBJV', 'SNFX', 'SBPL', 'SWXV',
#        'SBAR', 'SBNF', 'SBRF', 'SSZW', 'SWRD', 'SWLV', 'SSGP', 'SDOI',
#        'SBAE', 'SNDV', 'SSKS', 'SBMG', 'SBQV', 'SBIP', 'SBAT', 'SWFR',
# ...

# %%
df.loc[0,'ocorrencia_cidade']
# Out:
# 'RIO DE JANEIRO'

# %%
max(df.ocorrencia_dia.dt.year)
# Out:
# 2020

# %%
df.loc[2:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[0:2]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0    RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1             BELÉM            PA                 SBBE     2010-01-03
# 2    RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df['ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df.ocorrencia_cidade
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df['codigo_ocorrencia'].is_unique
# Out:
# True

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
#para salvar a mudança no dataframe posso salvar por cima ou usar o argumento inplace
#df = df.set_index('codigo_ocorrencia')
df.set_index('codigo_ocorrencia', inplace = True)

# %%
df.head()

# %%
df.loc[40349, 'ocorrencia_cidade']

# %%
# para voltar ao normal, temos o reset
df.reset_index(drop = True, inplace = True)

# %%
df.head()

# %%
# alterando valores
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df.loc[df.ocorrencia_uf == 'SP']
# aonde a ocorrencia_uf é igual a SP, a ocorrencia classificacao foi alterada para grave
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [markdown]
# ## Comecando a limpeza de fato

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep = ";", parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.isna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  ocorrencia_classificacao  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 5747              False               False                     False
# 5748              False               False                     False
# 5749              False               False                     False
# 5750              False               False                     False
# 5751              False               False                     False
#
#       ocorrencia_cidade  ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  \
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.replace(['**', '###!', '####', '****', '*****', 'NULL'], pd.NA, inplace = True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
#  ## Ao usar o pd.NA, o pandas me oferece formas de tratar os valores NA

# %%
df.fillna(10, inplace = True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             1
# total_recomendacoes         0
# dtype: int64

# %%
df.replace(10, pd.NA, inplace = True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            2
# dtype: int64

# %%
df.fillna(value = {'total_recomendacoes': 10}, inplace = True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df['coluna_teste'] = 20

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes  coluna_teste
# 0        12:00:00                    0            20
# ...

# %%
#Se eu deixar o padrao do axis = 0, ele tenta apagar a linha
#df.drop(['coluna_teste'], axis = 1, inplace = True)
# ou
df.drop(columns = 'coluna_teste', inplace = True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [markdown]
# ## Removendo linhas

# %%
df.set_index('ocorrencia_uf', inplace = True)

# %%
df.head()
# Out:
#                codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# ocorrencia_uf
# RJ                         40211               40211                INCIDENTE
# PA                         40349               40349                INCIDENTE
# RJ                         40351               40351                INCIDENTE
# MT                         39527               39527                 ACIDENTE
# RS                         40324               40324                INCIDENTE
#
#                 ocorrencia_cidade ocorrencia_aerodromo ocorrencia_dia  \
# ocorrencia_uf
# RJ                 RIO DE JANEIRO                 <NA>     2010-01-03
# PA                          BELÉM                 SBBE     2010-01-03
# RJ                 RIO DE JANEIRO                 SBRJ     2010-01-03
# MT             LUCAS DO RIO VERDE                 <NA>     2010-01-04
# RS                        PELOTAS                 SBPK     2010-01-05
#
# ...

# %%
# Removendo a UF RJ
df.drop("RJ", axis = 0, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-ec1b17cfc5ee> in <module>
#       1 # Removendo a UF RJ
# ----> 2 df.drop("RJ", axis = 0, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.head()
# Out:
#                codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# ocorrencia_uf
# PA                         40349               40349                INCIDENTE
# MT                         39527               39527                 ACIDENTE
# RS                         40324               40324                INCIDENTE
# BA                         39807               39807                INCIDENTE
# AM                         40215               40215                INCIDENTE
#
#                 ocorrencia_cidade ocorrencia_aerodromo ocorrencia_dia  \
# ocorrencia_uf
# PA                          BELÉM                 SBBE     2010-01-03
# MT             LUCAS DO RIO VERDE                 <NA>     2010-01-04
# RS                        PELOTAS                 SBPK     2010-01-05
# BA                       SALVADOR                 <NA>     2010-01-06
# AM                          COARI                 SBUY     2010-01-07
#
# ...

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#   ocorrencia_uf  codigo_ocorrencia  codigo_ocorrencia2  \
# 0            PA              40349               40349
# 1            MT              39527               39527
# 2            RS              40324               40324
# 3            BA              39807               39807
# 4            AM              40215               40215
#
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_aerodromo  \
# 0                INCIDENTE               BELÉM                 SBBE
# 1                 ACIDENTE  LUCAS DO RIO VERDE                 <NA>
# 2                INCIDENTE             PELOTAS                 SBPK
# 3                INCIDENTE            SALVADOR                 <NA>
# 4                INCIDENTE               COARI                 SBUY
#
#   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03        11:05:00                    0
# 1     2010-01-04        17:30:00                    0
# 2     2010-01-05        19:25:00                    0
# ...

# %% [markdown]
# ## posso excluir todos os valores que possuem NA

# %%
# remove todos os NA
df.dropna()
# Out:
#      ocorrencia_uf  codigo_ocorrencia  codigo_ocorrencia2  \
# 0               PA              40349               40349
# 2               RS              40324               40324
# 4               AM              40215               40215
# 6               PR              39156               39156
# 9               SP              40069               40069
# ...            ...                ...                 ...
# 5226            PR              79751               79751
# 5228            SP              79800               79800
# 5229            MG              79824               79824
# 5232            AC              79769               79769
# 5233            SP              79804               79804
#
#      ocorrencia_classificacao          ocorrencia_cidade ocorrencia_aerodromo  \
# 0                   INCIDENTE                      BELÉM                 SBBE
# 2                   INCIDENTE                    PELOTAS                 SBPK
# ...

# %%
# deleto os NA apenas da coluna ocorrencia_uf
df.dropna(subset = ['ocorrencia_uf'])
# Out:
#      ocorrencia_uf  codigo_ocorrencia  codigo_ocorrencia2  \
# 0               PA              40349               40349
# 1               MT              39527               39527
# 2               RS              40324               40324
# 3               BA              39807               39807
# 4               AM              40215               40215
# ...            ...                ...                 ...
# 5231            PR              79755               79755
# 5232            AC              79769               79769
# 5233            SP              79804               79804
# 5234            TO              79757               79757
# 5235            MS              79756               79756
#
#      ocorrencia_classificacao   ocorrencia_cidade ocorrencia_aerodromo  \
# 0                   INCIDENTE               BELÉM                 SBBE
# 1                    ACIDENTE  LUCAS DO RIO VERDE                 <NA>
# ...

# %%
df.drop_duplicates()
# Out:
#      ocorrencia_uf  codigo_ocorrencia  codigo_ocorrencia2  \
# 0               PA              40349               40349
# 1               MT              39527               39527
# 2               RS              40324               40324
# 3               BA              39807               39807
# 4               AM              40215               40215
# ...            ...                ...                 ...
# 5231            PR              79755               79755
# 5232            AC              79769               79769
# 5233            SP              79804               79804
# 5234            TO              79757               79757
# 5235            MS              79756               79756
#
#      ocorrencia_classificacao   ocorrencia_cidade ocorrencia_aerodromo  \
# 0                   INCIDENTE               BELÉM                 SBBE
# 1                    ACIDENTE  LUCAS DO RIO VERDE                 <NA>
# ...
